# %% [markdown]
# # Market Research on Airbnb Rentals in London

# %% [markdown]
# *Author: Raeesa Mansoor (CodeOp Student 1st year)*

# %% [markdown]
# #### Contents
#
# 1. Introduction
# 2. Aims and Objectives
# 3. My Questions
# 4. Importing the necessary files
# 5. Cleaning the data
# 6. Answering the questions
# 7. Conclusion

# %% [markdown]
# #### Introduction
#
# Airbnb, Inc. is an American company operating an online marketplace for short-and-long-term homestays and experiences in various countries and regions. It acts as a broker and charges a commission from each booking. Airbnb was founded in 2008 by Brian Chesky, Nathan Blecharczyk, and Joe Gebbia.
#
# In 2021 alone Airbnb recorded £225billion in revenue from its listings with £281.17 million comming from the city of London alone. This got me thinking about starting my own Airbnb business to get a slice of the pie.

# %% [markdown]
# #### Aims and Objectives
#
# The aim of this report is to produce market research material on what makes a profitable listing for an Airbnb in London. Hopefully, this will help me make an informed decsion as to what type of property to purchase, what price to set it at, and what location it should be in.

# %% [markdown]
# #### My Questions
#
# - Which areas in London have the highest priced listings?
# - What is the correlation between what type of accomodation is listed, and the price? Does this matter at all?
# - How do the reviews of a listing affect the price?

# %% [markdown]
# #### Importing the necessary data

# %% [markdown]
# ##### a) Important the tools required for EDA

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# *For some unknown reason, numpy refuses to load. Unfortunately this will affect the analysis later on, but we willdo our best with whatever data we have.*

# %% [markdown]
# ##### b) Importing the data set

# %%
listings = pd.read_csv(r'C:\Users\raees\Desktop\Codeop_activities\CodeOp_EDA_Nov_2024\listings.csv')

# %%
listings
# Out:
#                         id                                               name  \
# 0                   116268  Double Room (Unavailable for check in 31Dec-1Jan)
# 1                   117203            A stylish Victorian home in West London
# 2                   127652                    Contemporary central London apt
# 3                   127860  Double bedroom in cottage Twickenham (sleeps 1-2)
# 4                   131444                         Apartment close to centre.
# ...                    ...                                                ...
# 96177  1239087592369786950      Family Friendly Kentish Town by MoreThanStays
# 96178  1239112017665871678      The Naughty Nautical-Borough- by Frankie Says
# 96179  1239112357239275295       The Cheeky Hideaway-Borough- by Frankie Says
# 96180  1239116439240556456  The Shard-View Shindig - Borough - by Frankie ...
# 96181  1239118358582762076                          Amazing 3Bedroom Property
#
# ...

# %% [markdown]
# #### Cleaning the Data

# %%
listings.shape
#This will tell me how many rows (96182) and how many columns(18) I have.
# Out:
# (96182, 18)

# %%
listings.dropna(
    subset=['price', 'neighbourhood', 'room_type', 'number_of_reviews']
)
#Now we can remove any values which are nan
# Out:
#                         id                                               name  \
# 0                   116268  Double Room (Unavailable for check in 31Dec-1Jan)
# 1                   117203            A stylish Victorian home in West London
# 2                   127652                    Contemporary central London apt
# 4                   131444                         Apartment close to centre.
# 5                   137581                     I Bedroom flat Tower of London
# ...                    ...                                                ...
# 96177  1239087592369786950      Family Friendly Kentish Town by MoreThanStays
# 96178  1239112017665871678      The Naughty Nautical-Borough- by Frankie Says
# 96179  1239112357239275295       The Cheeky Hideaway-Borough- by Frankie Says
# 96180  1239116439240556456  The Shard-View Shindig - Borough - by Frankie ...
# 96181  1239118358582762076                          Amazing 3Bedroom Property
#
# ...

# %% [markdown]
# I can see that the na rows have dropped as before I had 96182 rows, and now I have 63205 rows.

# %%
listings = listings.reset_index(drop=True)
#This is to reset the indexes

# %%
listings.dtypes
#This will tell me the data type for each column, I can see which is appropriate or if there are errors. 
# All the data looks correctly data typed for now, so there is no need to change this. 
# I am mostly interested in the price, and the newiberhood. these are in float and object respectively.
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# dtype: object

# %%
#I will now check for duplicates, as this will skew my data. 
listings=listings.duplicated()

#Nothing is showing up, which means this data has no duplicates. ALl good to go

# %%
#I will now do value counts of the relevent colums to ensure everything is in order. 

listings['neighbourhood'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 #I will now do value counts of the relevent colums to ensure everything is in order.
# ----> 3 listings['neighbourhood'].value_counts()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# ...

# %%
listings['price'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 listings['price'].value_counts()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
# ...

# %%
listings['room_type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 listings['room_type'].value_counts()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
# ...

# %%
listings['number_of_reviews'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 listings['number_of_reviews'].value_counts()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
# ...

# %% [markdown]
# Now that I have cleaned the data set, I think I am ready to start analysing and visualising the results. Lets go one question at a time.

# %% [markdown]
# #### Question 1: Which areas in London have the highest priced listings?

# %%
#Lets create a histogram to view this data. 


sns.histplot(
    data=listings, 
    x="neighbourhood",
    y='price',
    estimator='mean'
)

#Now a graph is meaningless without the correct labels, so lets add the labels. 
plt.title("The Average Price GBP of a rental in London Neighbourhoods")
plt.xlabel("Neighbourhoods in London")
plt.xlabel("average Price of a rental GBP")

plt.show()

#I have tried really really hard to make this work, over and over again, but still no luck. 
# I think this may be because numpy has refused to install and i dont know what to do about it.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 6
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
# ----> 6 sns.histplot(
#       7     data=listings,
#       8     x="neighbourhood",
#       9     y='price',
#      10     estimator='mean'
#      11 )
#      13 #Now a graph is meaningless without the correct labels, so lets add the labels.
#      14 plt.title("The Average Price GBP of a rental in London Neighbourhoods")
#
# ...

# %% [markdown]
# Presuming I could see the bar chart, I would now have made some key observation thus:
#
# The neighbourhood which has the hihgest average price is ___
# The neighbourhood which has the lowest average price is ___
#
# Therefore, we can conclude that rentals are the most expensive in the___ area of London and I should consider purchasing a property in this area for a profitable business venture.

# %% [markdown]
# #### Question2: What is the correlation between what type of accomodation is listed, and the price? Does this matter at all?

# %%
#This question we need to break down a little further. 

sns.catplot(data=listings,
             x="price", 
             y="room_type", 
             kind="box")

#Now a graph is meaningless without the correct labels, so lets add the labels. 
plt.title("The Average Price GBP of different room types in London")
plt.xlabel("The type of rental room")
plt.xlabel("average Price of a rental GBP")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 3
#       1 #This question we need to break down a little further.
# ----> 3 sns.catplot(data=listings,
#       4              x="price",
#       5              y="room_type",
#       6              kind="box")
#       8 #Now a graph is meaningless without the correct labels, so lets add the labels.
#       9 plt.title("The Average Price GBP of different room types in London")
#
# ...

# %% [markdown]
# Again, I am unable to see the plot. We are going to pretend its worked. Hopefully there would be a distribution of data showing that _____ room type seems to be the highest mean price, and that _____ room type has the lowest mean price.
#
# This shows that the type of accomodation, room type does indeed matter. It cannot be ignored and has to be taken into consideration for a sensible business venture.
#
# This means that if I wanted to earn the highest rental, I should rent out a _____ room type. It seems the most profitable. If I could not afford to purchase this, then I would go for a ___ room type which is second most highest in price. On no account would I go for a ____ room type since it had thelowest mean price.

# %% [markdown]
# #### Question 3: - How do the reviews of a listing affect the price?

# %%
sns.scatterplot(data=listings, x="price", y="number_of_reviews")
#Now a graph is meaningless without the correct labels, so lets add the labels. 
plt.title("A correlation between the price of a rental and the number of reviews")
plt.xlabel("The price of a rental GBP")
plt.xlabel("The number of reviews on a rental")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sns.scatterplot(data=listings, x="price", y="number_of_reviews")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %% [markdown]
# So once again, I'm a little stumped. Ideally if it had worked we would have seen a lovely scattergram, and been able to conclude something from the data.
# If I had seen it, I could have edited it based on the dot colours to reflect the diversity in price.
#
# For the sake of formality. lets pretend it has worked. So looking at the data, we are going to pretend that there is a relationship between the reviews and the price.  Therefore, if I wanted to start up my own Air bnb, I would ensure that my price is in the bracket that creates most reviews. Reviews = trust, so they are important for a business.

# %% [markdown]
# #### Further Research

# %% [markdown]
# In order to research further for a more detailed analysis, I would look at how the differnt amenities within the listing that affect the price.
#
# Proposed questions going further:
# - Approximately how many amenities does a listing have in each of the areas?
# - Do the number of amenities affect the price of a listing?
# - Which amenities are mentioned in the reviews? Can we do a keyword search?

# %% [markdown]
# #### Conclusion
#
# In conclusion I have learnt that should I wish to purchase a property in London, I should do so in ___ area, with a room type that is ____.

# %% [markdown]
# ![my_dream_house](C:\\Users\\raees\\Desktop\\Codeop_activities\\CodeOp_EDA_Nov_2024\\my dream house .jpg)

# %% [markdown]
# #### Notes for the reader
#
# I hope you have enjoyed my EDA on Airbnb lisitings. I  look forward to any feedback you may have, and how I can improve my queries going forward. Any constructive criticism is greatly appreciated.
#
# Have a great day!
